# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# plotting a horizontal line across the map over latitude -20
fp = "BRA_adm1.shp"
map_df = gpd.read_file(fp)
map_df.plot()
plt.axhline(y=-20, color='r', linestyle='-')
plt.show()
